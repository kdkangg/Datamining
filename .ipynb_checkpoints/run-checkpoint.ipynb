# %%
# %run KNN.ipynb
# Out:
# CPU times: user 2min 3s, sys: 28.4 s, total: 2min 31s
# Wall time: 24.8 s
# precision: 0.3461633780283666, recall: 0.23057644110275688, f1score: 0.25211041812770585
# CPU times: user 114 ms, sys: 21.9 ms, total: 136 ms
# Wall time: 20.1 ms
# training data
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       337
#          1.0       1.00      1.00      1.00       337
#          2.0       1.00      1.00      1.00       337
#          3.0       1.00      1.00      1.00       337
#          4.0       1.00      1.00      1.00       337
#          5.0       0.99      1.00      1.00       337
#          6.0       1.00      1.00      1.00       337
#          7.0       1.00      1.00      1.00       337
#          8.0       1.00      1.00      1.00       337
#          9.0       1.00      1.00      1.00       337
#         10.0       1.00      1.00      1.00       337
#
#     accuracy                           1.00      3707
# ...

# %%
# %run naive_bayes_gaussian.ipynb
# Out:
# precision: 0.07055418396738114, recall: 0.12280701754385964, f1score: 0.08913910391742903
# CPU times: user 15.1 ms, sys: 4.6 ms, total: 19.7 ms
# Wall time: 6.01 ms

# %%
# %run SVM.ipynb
# Out:
# CPU times: user 2min 12s, sys: 436 ms, total: 2min 12s
# Wall time: 2min 12s
# precision: 0.3078885171377426, recall: 0.2907268170426065, f1score: 0.2968986170177067
# CPU times: user 530 ms, sys: 2.22 ms, total: 532 ms
# Wall time: 532 ms
# training data
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       337
#          1.0       1.00      1.00      1.00       337
#          2.0       1.00      1.00      1.00       337
#          3.0       0.99      1.00      1.00       337
#          4.0       1.00      1.00      1.00       337
#          5.0       1.00      0.99      1.00       337
#          6.0       1.00      1.00      1.00       337
#          7.0       1.00      1.00      1.00       337
#          8.0       1.00      1.00      1.00       337
#          9.0       1.00      1.00      1.00       337
#         10.0       1.00      1.00      1.00       337
#
#     accuracy                           1.00      3707
# ...

# %%
# %run Decision_Tree.ipynb
# Out:
# precision: 0.31974806718223037, recall: 0.21553884711779447, f1score: 0.22133669941298986
# CPU times: user 130 ms, sys: 510 µs, total: 130 ms
# Wall time: 130 ms
# training data
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.91      0.91       337
#          1.0       0.85      0.99      0.92       337
#          2.0       0.29      0.87      0.44       337
#          3.0       0.00      0.00      0.00       337
#          4.0       0.38      0.11      0.17       337
#          5.0       0.48      0.32      0.39       337
#          6.0       0.37      0.33      0.35       337
#          7.0       0.46      0.13      0.21       337
#          8.0       0.44      0.72      0.55       337
#          9.0       0.95      0.99      0.97       337
#         10.0       0.98      1.00      0.99       337
#
#     accuracy                           0.58      3707
#    macro avg       0.55      0.58      0.54      3707
# ...

# %%
# %run MLP.ipynb
# Out:
# CPU times: user 41min 49s, sys: 11min 27s, total: 53min 16s
# Wall time: 11min 7s
# precision: 0.3796944100131467, recall: 0.2907268170426065, f1score: 0.31530718596801227
# CPU times: user 18.1 s, sys: 4.83 s, total: 22.9 s
# Wall time: 4.67 s
# training data
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.97       337
#          1.0       0.99      0.99      0.99       337
#          2.0       0.88      0.93      0.91       337
#          3.0       0.68      0.79      0.73       337
#          4.0       0.63      0.56      0.59       337
#          5.0       0.67      0.41      0.51       337
#          6.0       0.57      0.72      0.63       337
#          7.0       0.78      0.67      0.72       337
#          8.0       0.82      0.92      0.87       337
#          9.0       0.99      1.00      1.00       337
#         10.0       1.00      1.00      1.00       337
#
#     accuracy                           0.82      3707
# ...

# %%
# %run Randomforest.ipynb
# Out:
# CPU times: user 4min 14s, sys: 1.9 s, total: 4min 16s
# Wall time: 4min 16s
# precision: 0.37116276115002433, recall: 0.3508771929824561, f1score: 0.3580459441034593
# CPU times: user 3.48 s, sys: 11.7 ms, total: 3.5 s
# Wall time: 3.5 s
# training data
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       337
#          1.0       1.00      1.00      1.00       337
#          2.0       1.00      1.00      1.00       337
#          3.0       1.00      1.00      1.00       337
#          4.0       1.00      1.00      1.00       337
#          5.0       0.99      1.00      1.00       337
#          6.0       1.00      1.00      1.00       337
#          7.0       1.00      1.00      1.00       337
#          8.0       1.00      1.00      1.00       337
#          9.0       1.00      1.00      1.00       337
#         10.0       1.00      1.00      1.00       337
#
#     accuracy                           1.00      3707
# ...
