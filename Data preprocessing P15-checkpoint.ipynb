# %%
import pandas as pd
import numpy as np

# %%
#read data
calories15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/calories.json')
distance15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/distance.json')
l_act15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/lightly_active_minutes.json')
m_act15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/moderately_active_minutes.json')
r_heart15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/resting_heart_rate.json')
sedentary15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/sedentary_minutes.json')
sleep_score15 = pd.read_csv('osfstorage-archive/pmdata/p15/fitbit/sleep_score.csv')
sleep15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/sleep.json')
steps15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/steps.json')
hr_zone15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/time_in_heart_rate_zones.json')
v_act15 = pd.read_json('osfstorage-archive/pmdata/p15/fitbit/very_active_minutes.json')

# %%
#data frequency to date using sum
calories_processed = calories15.resample('D', on = 'dateTime').value.sum() 
distance_processed = distance15.resample('D', on = 'dateTime').value.sum()
steps_processed = steps15.resample('D', on = 'dateTime').value.sum()

# %%
#resting heart rate to simple df
r_heart15['value']=r_heart15['value'].apply(lambda x: x['value'])
r_heart_processed=r_heart15

# %%
#delete time in sleep score time stamp
sleep_score15['timestamp']=sleep_score15['timestamp'].apply(lambda x: x[:10])
#drop unnecessary column
sleep_score_processed = sleep_score15.drop(columns='sleep_log_entry_id')

# %%
#dictionary with heart rate zone minutes to df
hr_zone_value = pd.DataFrame([eval(str(a).replace('{\'valuesInZones\': ','').replace('}}','}')) for a in hr_zone15['value']])
hr_zone_processed = pd.concat([hr_zone15['dateTime'], hr_zone_value], axis=1)

# %%
#unify index
l_act_processed = l_act15.set_index('dateTime')
m_act_processed = m_act15.set_index('dateTime')
r_heart_processed = r_heart_processed.set_index('dateTime')
sedentary_processed = sedentary15.set_index('dateTime')
sleep_score_processed = sleep_score_processed.set_index('timestamp')
sleep_processed = sleep15.set_index('dateOfSleep')
hr_zone_processed = hr_zone_processed.set_index('dateTime')
v_act_processed = v_act15.set_index('dateTime')
#index to DateTimeIndex
sleep_score_processed.index = pd.to_datetime(sleep_score_processed.index)

# %%
#get dummy values for mainsleep true(1)/false(0)
sleep_processed['mainSleep'] = pd.get_dummies(sleep_processed['mainSleep'])[True].fillna(0)
#drop unnecessary columns
sleep_processed = sleep_processed.drop(['logId','startTime','endTime','type','infoCode','levels'], axis=1)
#index to DateTimeIndex
sleep_processed.index = pd.to_datetime(sleep_processed.index)

# %%
#read prediction target
wellness = pd.read_csv('osfstorage-archive/pmdata/p15/pmsys/wellness.csv') 
wellness['effective_time_frame'] = wellness['effective_time_frame'].apply(lambda x: x[:10])
wellness = wellness.rename(columns={"effective_time_frame": "dateTime"})
readiness = wellness.loc[:,['dateTime','readiness']].set_index('dateTime')
readiness.index = pd.to_datetime(readiness.index)

# %%
#drop duplicated records
readiness, calories_processed,distance_processed,l_act_processed,m_act_processed,r_heart_processed,sedentary_processed,sleep_score_processed,sleep_processed,steps_processed,hr_zone_processed,v_act_processed = [x[~x.index.duplicated(keep='first')] for x in [readiness, calories_processed,distance_processed,l_act_processed,m_act_processed,r_heart_processed,sedentary_processed,sleep_score_processed,sleep_processed,steps_processed,hr_zone_processed,v_act_processed]]

# %%
#concat data
P15 = pd.concat([readiness, calories_processed,distance_processed,l_act_processed,m_act_processed,r_heart_processed,sedentary_processed,sleep_score_processed,sleep_processed,steps_processed,hr_zone_processed,v_act_processed], axis=1)

# %%
#rename columns
P15.columns=['readiness','calories','distance','l_act','m_act','resting_heart','sedentary','sleep_overall_score','sleep_composition_score',
             'sleep_revitalization_score', 'sleep_duration_score',
             'deep_sleep_in_minutes', 'sleep_resting_heart_rate','sleep_restlessness',
             'sleep_duration','sleep_minutesToFallAsleep','sleep_minutesAsleep','sleep_minutesAwake',
             'sleep_minutesAfterWakeup','sleep_timeInBed','sleep_efficiency',
             'main_sleep','steps',
             'hr_below_zone1', 'hr_zone1', 'hr_zone3','hr_zone2','v_act']

# %%
P15
# Out:
#             readiness  calories   distance  l_act  m_act  resting_heart  \
# 2019-11-08        NaN   1641.60        NaN    0.0    0.0       0.000000
# 2019-11-09        NaN   2319.38   384520.0  159.0   13.0      58.000000
# 2019-11-10        NaN   3566.68  1136180.0  237.0   42.0      57.807162
# 2019-11-11        NaN   2907.30  1005990.0  229.0   20.0      57.207714
# 2019-11-12        NaN   3330.25  1561210.0  201.0   16.0      56.461736
# ...               ...       ...        ...    ...    ...            ...
# 2020-03-28        8.0   3705.36   234540.0  160.0   10.0      49.796299
# 2020-03-29        6.0   3199.57  1028980.0  211.0   24.0      49.703032
# 2020-03-30        5.0   3566.68   240390.0  186.0   10.0      49.322347
# 2020-03-31        NaN   3034.19   733780.0  228.0   39.0      49.231117
# 2020-04-01        NaN       NaN        NaN    NaN    NaN            NaN
#
#             sedentary  sleep_overall_score  sleep_composition_score  \
# ...
