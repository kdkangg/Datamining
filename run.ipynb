# %%
#without excluding P05 zero readiness
print('KNN')
# %run KNN.ipynb
print('SVM')
# %run SVM.ipynb
print('Decision Tree')
# %run Decision_Tree.ipynb
print('Multilayer Perceptron')
# %run MLP.ipynb
print('Randomforest')
# %run Randomforest.ipynb
# Out:
# KNN
# CPU times: user 12.9 s, sys: 2.98 s, total: 15.8 s
# Wall time: 2.92 s
# precision: 0.4055957869474035, recall: 0.23809523809523808, f1score: 0.2685194458695908
# CPU times: user 118 ms, sys: 23.5 ms, total: 141 ms
# Wall time: 23.6 ms
# training data
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       337
#          1.0       1.00      1.00      1.00       337
#          2.0       1.00      1.00      1.00       337
#          3.0       1.00      1.00      1.00       337
#          4.0       1.00      1.00      1.00       337
#          5.0       0.99      1.00      1.00       337
#          6.0       1.00      1.00      1.00       337
#          7.0       1.00      1.00      1.00       337
#          8.0       1.00      1.00      1.00       337
#          9.0       1.00      1.00      1.00       337
#         10.0       1.00      1.00      1.00       337
#
#     accuracy                           1.00      3707
# ...

# %%
#exclyding P05 zero readiness
print('KNN')
# %run KNN_V2.ipynb
print('SVM')
# %run SVM_V2.ipynb
print('Decision Tree')
# %run Decision_Tree_V2.ipynb
print('Multilayer Perceptron')
# %run MLP_V2.ipynb
print('Randomforest')
# %run Randomforest_V2.ipynb
# Out:
# KNN
# CPU times: user 13.3 s, sys: 2.86 s, total: 16.2 s
# Wall time: 3.19 s
# precision: 0.369805953417872, recall: 0.28125, f1score: 0.30932789536772587
# CPU times: user 94.5 ms, sys: 17.6 ms, total: 112 ms
# Wall time: 18.4 ms
# training data
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       351
#          1.0       1.00      1.00      1.00       351
#          2.0       1.00      1.00      1.00       351
#          3.0       1.00      1.00      1.00       351
#          4.0       1.00      1.00      1.00       351
#          5.0       0.99      1.00      1.00       351
#          6.0       1.00      1.00      1.00       351
#          7.0       1.00      1.00      1.00       351
#          8.0       1.00      1.00      1.00       351
#          9.0       1.00      1.00      1.00       351
#         10.0       1.00      1.00      1.00       351
#
#     accuracy                           1.00      3861
# ...
