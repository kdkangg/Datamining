# %%
# %run KNN.ipynb
# Out:
# CPU times: user 2min 16s, sys: 32.1 s, total: 2min 48s
# Wall time: 28 s
# precision: 0.3579199087501934, recall: 0.2681704260651629, f1score: 0.29476127153338094
# CPU times: user 98 ms, sys: 19.8 ms, total: 118 ms
# Wall time: 19.2 ms

# %%
# %run naive_bayes_gaussian.ipynb

# %%
# %run SVM.ipynb

# %%
# %run Decision_Tree.ipynb

# %%
# %run MLP.ipynb

# %%
# %run Randomforest.ipynb
