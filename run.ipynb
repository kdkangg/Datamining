# %%
# %run KNN.ipynb
# Out:
# CPU times: user 1min 44s, sys: 23.8 s, total: 2min 8s
# Wall time: 22.5 s
# precision: 0.37560489382393153, recall: 0.30708661417322836, f1score: 0.3280167575888394
# CPU times: user 90 ms, sys: 18.5 ms, total: 109 ms
# Wall time: 16.8 ms
# training data
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       352
#          2.0       1.00      1.00      1.00       352
#          3.0       1.00      1.00      1.00       352
#          4.0       1.00      1.00      1.00       352
#          5.0       0.99      1.00      1.00       352
#          6.0       1.00      1.00      1.00       352
#          7.0       1.00      1.00      1.00       352
#          8.0       1.00      1.00      1.00       352
#          9.0       1.00      1.00      1.00       352
#         10.0       1.00      1.00      1.00       352
#
#     accuracy                           1.00      3520
#    macro avg       1.00      1.00      1.00      3520
# ...

# %%
# %run naive_bayes_gaussian.ipynb
# Out:
# precision: 0.16129910383290288, recall: 0.13123359580052493, f1score: 0.09429163170753474
# CPU times: user 17.8 ms, sys: 7.37 ms, total: 25.2 ms
# Wall time: 5.53 ms

# %%
# %run SVM.ipynb
# Out:
# CPU times: user 2min 13s, sys: 779 ms, total: 2min 14s
# Wall time: 2min 14s
# precision: 0.2940774015988941, recall: 0.30446194225721784, f1score: 0.296857555564328
# CPU times: user 657 ms, sys: 5.35 ms, total: 662 ms
# Wall time: 662 ms
# training data
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       352
#          2.0       1.00      1.00      1.00       352
#          3.0       1.00      1.00      1.00       352
#          4.0       1.00      0.99      1.00       352
#          5.0       0.99      1.00      1.00       352
#          6.0       1.00      1.00      1.00       352
#          7.0       1.00      1.00      1.00       352
#          8.0       1.00      1.00      1.00       352
#          9.0       1.00      1.00      1.00       352
#         10.0       1.00      1.00      1.00       352
#
#     accuracy                           1.00      3520
#    macro avg       1.00      1.00      1.00      3520
# ...

# %%
# %run Decision_Tree.ipynb
# Out:
# precision: 0.4159167119916271, recall: 0.2650918635170604, f1score: 0.2894078796256192
# CPU times: user 133 ms, sys: 634 µs, total: 134 ms
# Wall time: 134 ms
# training data
#               precision    recall  f1-score   support
#
#          1.0       0.83      0.99      0.90       352
#          2.0       0.37      0.77      0.50       352
#          3.0       0.28      0.22      0.25       352
#          4.0       0.44      0.30      0.36       352
#          5.0       0.83      0.28      0.42       352
#          6.0       0.34      0.31      0.32       352
#          7.0       0.45      0.03      0.05       352
#          8.0       0.42      0.80      0.55       352
#          9.0       0.97      1.00      0.98       352
#         10.0       0.97      1.00      0.99       352
#
#     accuracy                           0.57      3520
#    macro avg       0.59      0.57      0.53      3520
# weighted avg       0.59      0.57      0.53      3520
#
# test data
# ...

# %%
# %run MLP.ipynb
# Out:
# CPU times: user 37min 29s, sys: 11min 4s, total: 48min 33s
# Wall time: 11min 23s
# precision: 0.35280701339153603, recall: 0.30446194225721784, f1score: 0.3212293038841843
# CPU times: user 20.5 s, sys: 5.09 s, total: 25.6 s
# Wall time: 5.97 s
# training data
#               precision    recall  f1-score   support
#
#          1.0       0.97      1.00      0.98       352
#          2.0       0.76      0.90      0.82       352
#          3.0       0.73      0.62      0.67       352
#          4.0       0.61      0.59      0.60       352
#          5.0       0.69      0.49      0.57       352
#          6.0       0.61      0.69      0.65       352
#          7.0       0.68      0.69      0.69       352
#          8.0       0.78      0.82      0.80       352
#          9.0       0.98      1.00      0.99       352
#         10.0       1.00      1.00      1.00       352
#
#     accuracy                           0.78      3520
#    macro avg       0.78      0.78      0.78      3520
# ...

# %%
# %run Randomforest.ipynb
# Out:
# CPU times: user 3min 43s, sys: 1.37 s, total: 3min 44s
# Wall time: 3min 44s
# precision: 0.33296482831849966, recall: 0.34120734908136485, f1score: 0.3347217916595669
# CPU times: user 961 ms, sys: 3.59 ms, total: 964 ms
# Wall time: 964 ms
# training data
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       352
#          2.0       1.00      1.00      1.00       352
#          3.0       1.00      1.00      1.00       352
#          4.0       1.00      1.00      1.00       352
#          5.0       0.99      1.00      1.00       352
#          6.0       1.00      1.00      1.00       352
#          7.0       1.00      1.00      1.00       352
#          8.0       1.00      1.00      1.00       352
#          9.0       1.00      1.00      1.00       352
#         10.0       1.00      1.00      1.00       352
#
#     accuracy                           1.00      3520
#    macro avg       1.00      1.00      1.00      3520
# ...
